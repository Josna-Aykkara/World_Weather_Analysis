# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000) # YOUR CODE HERE
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000) # YOUR CODE HERE

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
from citipy import citipy

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 730

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE  
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | clyde river
# Processing Record 2 of Set 1 | cidreira
# Processing Record 3 of Set 1 | vostok
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | muros
# Processing Record 6 of Set 1 | srednekolymsk
# Processing Record 7 of Set 1 | amahai
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | moscow
# Processing Record 10 of Set 1 | talnakh
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | luanda
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | play cu
# City not found. Skipping...
# Processing Record 16 of Set 1 | chapais
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | salalah
# Processing Record 23 of Set 1 | elliot lake
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | bengkulu
# Processing Record 29 of Set 1 | constitucion
# Processing Record 30 of Set 1 | ponta do sol
# Processing Record 31 of Set 1 | luderitz
# Processing Record 32 of Set 1 | lazaro cardenas
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | mandalgovi
# Processing Record 35 of Set 1 | vaitape
# Processing Record 36 of Set 1 | acapulco
# Processing Record 37 of Set 1 | severo-kurilsk
# Processing Record 38 of Set 1 | dabakala
# Processing Record 39 of Set 1 | tsienyane
# City not found. Skipping...
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | los llanos de aridane
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | mtwara
# Processing Record 44 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 1 | san cristobal
# Processing Record 46 of Set 1 | pinerolo
# Processing Record 47 of Set 1 | umm kaddadah
# Processing Record 48 of Set 1 | armacao dos buzios
# City not found. Skipping...
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | faanui
# Processing Record 2 of Set 2 | itaituba
# Processing Record 3 of Set 2 | nouadhibou
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | torbay
# Processing Record 7 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 2 | auki
# Processing Record 9 of Set 2 | victoria
# Processing Record 10 of Set 2 | nizhnevartovsk
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | hay river
# Processing Record 13 of Set 2 | synya
# Processing Record 14 of Set 2 | macaboboni
# City not found. Skipping...
# Processing Record 15 of Set 2 | ambilobe
# Processing Record 16 of Set 2 | bermeo
# Processing Record 17 of Set 2 | pevek
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | bulaevo
# Processing Record 20 of Set 2 | cabo san lucas
# Processing Record 21 of Set 2 | bonavista
# Processing Record 22 of Set 2 | fare
# Processing Record 23 of Set 2 | praya
# Processing Record 24 of Set 2 | macenta
# Processing Record 25 of Set 2 | haines junction
# Processing Record 26 of Set 2 | lavrentiya
# Processing Record 27 of Set 2 | lompoc
# Processing Record 28 of Set 2 | chokurdakh
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | hasaki
# Processing Record 35 of Set 2 | pemangkat
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | otradnoye
# Processing Record 38 of Set 2 | lipari
# Processing Record 39 of Set 2 | ostrovnoy
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | busselton
# Processing Record 42 of Set 2 | doume
# Processing Record 43 of Set 2 | coihaique
# Processing Record 44 of Set 2 | konstantinovka
# Processing Record 45 of Set 2 | sapa
# Processing Record 46 of Set 2 | kautokeino
# Processing Record 47 of Set 2 | tasiilaq
# Processing Record 48 of Set 2 | port augusta
# Processing Record 49 of Set 2 | katsuura
# Processing Record 50 of Set 2 | samarai
# Processing Record 1 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 3 | airai
# Processing Record 3 of Set 3 | kavieng
# Processing Record 4 of Set 3 | pasighat
# Processing Record 5 of Set 3 | nanortalik
# Processing Record 6 of Set 3 | ouricuri
# Processing Record 7 of Set 3 | blythe
# Processing Record 8 of Set 3 | port macquarie
# Processing Record 9 of Set 3 | margate
# Processing Record 10 of Set 3 | sao filipe
# Processing Record 11 of Set 3 | petropavlovskoye
# Processing Record 12 of Set 3 | luorong
# Processing Record 13 of Set 3 | cockburn town
# Processing Record 14 of Set 3 | lima
# Processing Record 15 of Set 3 | duz
# City not found. Skipping...
# Processing Record 16 of Set 3 | hobart
# Processing Record 17 of Set 3 | yeppoon
# Processing Record 18 of Set 3 | lapas
# Processing Record 19 of Set 3 | tuatapere
# Processing Record 20 of Set 3 | svetlogorsk
# Processing Record 21 of Set 3 | okhotsk
# Processing Record 22 of Set 3 | rudkobing
# Processing Record 23 of Set 3 | harper
# Processing Record 24 of Set 3 | hithadhoo
# Processing Record 25 of Set 3 | muscat
# Processing Record 26 of Set 3 | merritt island
# Processing Record 27 of Set 3 | osa
# Processing Record 28 of Set 3 | kalispell
# Processing Record 29 of Set 3 | dikson
# Processing Record 30 of Set 3 | barrow
# Processing Record 31 of Set 3 | sobolevo
# Processing Record 32 of Set 3 | winnemucca
# Processing Record 33 of Set 3 | saint-philippe
# Processing Record 34 of Set 3 | safwah
# City not found. Skipping...
# Processing Record 35 of Set 3 | afgoye
# City not found. Skipping...
# Processing Record 36 of Set 3 | qaanaaq
# Processing Record 37 of Set 3 | sechura
# Processing Record 38 of Set 3 | aswan
# Processing Record 39 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 3 | mahenge
# Processing Record 41 of Set 3 | sakakah
# Processing Record 42 of Set 3 | simnas
# Processing Record 43 of Set 3 | chicama
# Processing Record 44 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 3 | ongandjera
# Processing Record 46 of Set 3 | kloulklubed
# Processing Record 47 of Set 3 | karnal
# Processing Record 48 of Set 3 | guarda
# Processing Record 49 of Set 3 | bredasdorp
# Processing Record 50 of Set 3 | sovetskiy
# Processing Record 1 of Set 4 | mataura
# Processing Record 2 of Set 4 | farsund
# Processing Record 3 of Set 4 | miraflores
# Processing Record 4 of Set 4 | new norfolk
# Processing Record 5 of Set 4 | longhua
# Processing Record 6 of Set 4 | isangel
# Processing Record 7 of Set 4 | khatanga
# Processing Record 8 of Set 4 | honningsvag
# Processing Record 9 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 4 | barra patuca
# Processing Record 11 of Set 4 | mahebourg
# Processing Record 12 of Set 4 | geraldton
# Processing Record 13 of Set 4 | tibagi
# Processing Record 14 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 4 | camargo
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | sitka
# Processing Record 18 of Set 4 | khorramabad
# Processing Record 19 of Set 4 | toulepleu
# City not found. Skipping...
# Processing Record 20 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 4 | qazvin
# Processing Record 22 of Set 4 | nishihara
# Processing Record 23 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 24 of Set 4 | plettenberg bay
# Processing Record 25 of Set 4 | aasiaat
# Processing Record 26 of Set 4 | acu
# Processing Record 27 of Set 4 | tongchuan
# Processing Record 28 of Set 4 | codrington
# Processing Record 29 of Set 4 | uvinza
# Processing Record 30 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 31 of Set 4 | palmer
# Processing Record 32 of Set 4 | puerto ayora
# Processing Record 33 of Set 4 | nosy varika
# Processing Record 34 of Set 4 | vila franca do campo
# Processing Record 35 of Set 4 | lake city
# Processing Record 36 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 4 | bambous virieux
# Processing Record 38 of Set 4 | yulara
# Processing Record 39 of Set 4 | mecca
# Processing Record 40 of Set 4 | lethem
# Processing Record 41 of Set 4 | pingzhuang
# Processing Record 42 of Set 4 | reconquista
# Processing Record 43 of Set 4 | hilo
# Processing Record 44 of Set 4 | iralaya
# Processing Record 45 of Set 4 | kerteh
# City not found. Skipping...
# Processing Record 46 of Set 4 | ulaanbaatar
# Processing Record 47 of Set 4 | esperance
# Processing Record 48 of Set 4 | pirovskoye
# Processing Record 49 of Set 4 | kahului
# Processing Record 50 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 5 | saint-augustin
# Processing Record 2 of Set 5 | nalut
# Processing Record 3 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 5 | xai-xai
# Processing Record 5 of Set 5 | batamshinskiy
# Processing Record 6 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 5 | mamburao
# Processing Record 8 of Set 5 | hobyo
# Processing Record 9 of Set 5 | hokitika
# Processing Record 10 of Set 5 | pacific grove
# Processing Record 11 of Set 5 | pangody
# Processing Record 12 of Set 5 | najran
# Processing Record 13 of Set 5 | port elizabeth
# Processing Record 14 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 5 | lata
# Processing Record 16 of Set 5 | ixtapa
# Processing Record 17 of Set 5 | pansoy
# Processing Record 18 of Set 5 | yarmouth
# Processing Record 19 of Set 5 | oranjemund
# Processing Record 20 of Set 5 | anadyr
# Processing Record 21 of Set 5 | ust-uda
# Processing Record 22 of Set 5 | sao joao da barra
# Processing Record 23 of Set 5 | santa maria
# Processing Record 24 of Set 5 | tecoanapa
# Processing Record 25 of Set 5 | vardo
# Processing Record 26 of Set 5 | mahon
# Processing Record 27 of Set 5 | winneba
# Processing Record 28 of Set 5 | kavaratti
# Processing Record 29 of Set 5 | bossangoa
# Processing Record 30 of Set 5 | te anau
# Processing Record 31 of Set 5 | camacha
# Processing Record 32 of Set 5 | lakatoro
# Processing Record 33 of Set 5 | katobu
# Processing Record 34 of Set 5 | houston
# Processing Record 35 of Set 5 | mantua
# Processing Record 36 of Set 5 | phan thiet
# Processing Record 37 of Set 5 | batticaloa
# Processing Record 38 of Set 5 | santa fe
# Processing Record 39 of Set 5 | ilulissat
# Processing Record 40 of Set 5 | chuy
# Processing Record 41 of Set 5 | bougouni
# Processing Record 42 of Set 5 | pisco
# Processing Record 43 of Set 5 | north bend
# Processing Record 44 of Set 5 | general roca
# Processing Record 45 of Set 5 | mercedes
# Processing Record 46 of Set 5 | khromtau
# Processing Record 47 of Set 5 | sortland
# Processing Record 48 of Set 5 | waipawa
# Processing Record 49 of Set 5 | leh
# Processing Record 50 of Set 5 | nogliki
# Processing Record 1 of Set 6 | krasnoshchekovo
# Processing Record 2 of Set 6 | cartagena
# Processing Record 3 of Set 6 | san patricio
# Processing Record 4 of Set 6 | molepolole
# Processing Record 5 of Set 6 | zhigalovo
# Processing Record 6 of Set 6 | amapa
# Processing Record 7 of Set 6 | talca
# Processing Record 8 of Set 6 | yerbogachen
# Processing Record 9 of Set 6 | borgarnes
# Processing Record 10 of Set 6 | cabinda
# Processing Record 11 of Set 6 | makakilo city
# Processing Record 12 of Set 6 | bathsheba
# Processing Record 13 of Set 6 | atar
# Processing Record 14 of Set 6 | yumen
# Processing Record 15 of Set 6 | assiniboia
# Processing Record 16 of Set 6 | ojinaga
# Processing Record 17 of Set 6 | christchurch
# Processing Record 18 of Set 6 | punta alta
# Processing Record 19 of Set 6 | zlatoustovsk
# City not found. Skipping...
# Processing Record 20 of Set 6 | ahipara
# Processing Record 21 of Set 6 | klaksvik
# Processing Record 22 of Set 6 | sosnovo-ozerskoye
# Processing Record 23 of Set 6 | naze
# Processing Record 24 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 6 | balikpapan
# Processing Record 26 of Set 6 | fort nelson
# Processing Record 27 of Set 6 | flinders
# Processing Record 28 of Set 6 | merrill
# Processing Record 29 of Set 6 | manakara
# Processing Record 30 of Set 6 | northam
# Processing Record 31 of Set 6 | envira
# Processing Record 32 of Set 6 | sur
# Processing Record 33 of Set 6 | sioux lookout
# Processing Record 34 of Set 6 | ust-kuyga
# Processing Record 35 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 36 of Set 6 | banjar
# Processing Record 37 of Set 6 | bilibino
# Processing Record 38 of Set 6 | hambantota
# Processing Record 39 of Set 6 | greystones
# Processing Record 40 of Set 6 | mogadishu
# Processing Record 41 of Set 6 | mar del plata
# Processing Record 42 of Set 6 | polewali
# Processing Record 43 of Set 6 | touros
# Processing Record 44 of Set 6 | vao
# Processing Record 45 of Set 6 | olafsvik
# Processing Record 46 of Set 6 | gualdo tadino
# Processing Record 47 of Set 6 | kantang
# Processing Record 48 of Set 6 | galle
# Processing Record 49 of Set 6 | cayenne
# Processing Record 50 of Set 6 | vilhena
# Processing Record 1 of Set 7 | saint george
# Processing Record 2 of Set 7 | mahajanga
# Processing Record 3 of Set 7 | lai
# Processing Record 4 of Set 7 | bilara
# Processing Record 5 of Set 7 | manzhouli
# Processing Record 6 of Set 7 | gat
# Processing Record 7 of Set 7 | port hardy
# Processing Record 8 of Set 7 | saldanha
# Processing Record 9 of Set 7 | homer
# Processing Record 10 of Set 7 | ugoofaaru
# Processing Record 11 of Set 7 | albania
# Processing Record 12 of Set 7 | santa cruz
# Processing Record 13 of Set 7 | qasigiannguit
# Processing Record 14 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 7 | joshimath
# Processing Record 16 of Set 7 | igra
# Processing Record 17 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 7 | wanning
# Processing Record 19 of Set 7 | nara
# Processing Record 20 of Set 7 | norman wells
# Processing Record 21 of Set 7 | nikolskoye
# Processing Record 22 of Set 7 | harindanga
# Processing Record 23 of Set 7 | thompson
# Processing Record 24 of Set 7 | dingle
# Processing Record 25 of Set 7 | wolsztyn
# Processing Record 26 of Set 7 | skjervoy
# Processing Record 27 of Set 7 | kodiak
# Processing Record 28 of Set 7 | vestmannaeyjar
# Processing Record 29 of Set 7 | zaraza
# Processing Record 30 of Set 7 | laguna
# Processing Record 31 of Set 7 | ust-nera
# Processing Record 32 of Set 7 | nuuk
# Processing Record 33 of Set 7 | zhovkva
# Processing Record 34 of Set 7 | santiago
# Processing Record 35 of Set 7 | sungairaya
# Processing Record 36 of Set 7 | kjollefjord
# Processing Record 37 of Set 7 | bat khela
# Processing Record 38 of Set 7 | bajil
# Processing Record 39 of Set 7 | iqaluit
# Processing Record 40 of Set 7 | meulaboh
# Processing Record 41 of Set 7 | aporawan
# City not found. Skipping...
# Processing Record 42 of Set 7 | abu dhabi
# Processing Record 43 of Set 7 | ondjiva
# Processing Record 44 of Set 7 | verkhneuralsk
# Processing Record 45 of Set 7 | gouyave
# Processing Record 46 of Set 7 | richards bay
# Processing Record 47 of Set 7 | berlevag
# Processing Record 48 of Set 7 | tobermory
# Processing Record 49 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 7 | kichera
# Processing Record 1 of Set 8 | novyy svit
# Processing Record 2 of Set 8 | sola
# Processing Record 3 of Set 8 | fortuna
# Processing Record 4 of Set 8 | bumbuna
# Processing Record 5 of Set 8 | torres
# Processing Record 6 of Set 8 | qaqortoq
# Processing Record 7 of Set 8 | port hedland
# Processing Record 8 of Set 8 | nome
# Processing Record 9 of Set 8 | namibe
# Processing Record 10 of Set 8 | russell
# Processing Record 11 of Set 8 | abha
# Processing Record 12 of Set 8 | pribyslav
# Processing Record 13 of Set 8 | sinnamary
# Processing Record 14 of Set 8 | kasongo-lunda
# Processing Record 15 of Set 8 | sorland
# Processing Record 16 of Set 8 | guerrero negro
# Processing Record 17 of Set 8 | grindavik
# Processing Record 18 of Set 8 | kragero
# Processing Record 19 of Set 8 | panguna
# Processing Record 20 of Set 8 | poroshkovo
# Processing Record 21 of Set 8 | goderich
# Processing Record 22 of Set 8 | rudbar
# Processing Record 23 of Set 8 | kamwenge
# Processing Record 24 of Set 8 | sai buri
# Processing Record 25 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 26 of Set 8 | moose factory
# Processing Record 27 of Set 8 | la orilla
# Processing Record 28 of Set 8 | porto nacional
# Processing Record 29 of Set 8 | leningradskiy
# Processing Record 30 of Set 8 | mudgee
# Processing Record 31 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 8 | huanuni
# Processing Record 33 of Set 8 | weyburn
# Processing Record 34 of Set 8 | holesov
# Processing Record 35 of Set 8 | bijar
# Processing Record 36 of Set 8 | kenora
# Processing Record 37 of Set 8 | adrar
# Processing Record 38 of Set 8 | peterhead
# Processing Record 39 of Set 8 | kamaishi
# Processing Record 40 of Set 8 | bilma
# Processing Record 41 of Set 8 | susehri
# Processing Record 42 of Set 8 | oktyabrskoye
# Processing Record 43 of Set 8 | keuruu
# Processing Record 44 of Set 8 | urumqi
# Processing Record 45 of Set 8 | kokstad
# Processing Record 46 of Set 8 | ciras
# City not found. Skipping...
# Processing Record 47 of Set 8 | asnaes
# Processing Record 48 of Set 8 | uusikaupunki
# Processing Record 49 of Set 8 | bela vista
# Processing Record 50 of Set 8 | nebaj
# Processing Record 1 of Set 9 | koroni
# Processing Record 2 of Set 9 | loikaw
# Processing Record 3 of Set 9 | victor harbor
# Processing Record 4 of Set 9 | ahar
# Processing Record 5 of Set 9 | mehamn
# Processing Record 6 of Set 9 | yar-sale
# Processing Record 7 of Set 9 | houma
# Processing Record 8 of Set 9 | porto tolle
# Processing Record 9 of Set 9 | pangnirtung
# Processing Record 10 of Set 9 | rameswaram
# Processing Record 11 of Set 9 | dymer
# Processing Record 12 of Set 9 | oil city
# Processing Record 13 of Set 9 | tual
# Processing Record 14 of Set 9 | iwanai
# Processing Record 15 of Set 9 | palora
# Processing Record 16 of Set 9 | varkaus
# Processing Record 17 of Set 9 | mainz
# Processing Record 18 of Set 9 | coolum beach
# Processing Record 19 of Set 9 | mayumba
# Processing Record 20 of Set 9 | nantucket
# Processing Record 21 of Set 9 | dzhida
# Processing Record 22 of Set 9 | nioro
# Processing Record 23 of Set 9 | fairbanks
# Processing Record 24 of Set 9 | baghdad
# Processing Record 25 of Set 9 | honiara
# Processing Record 26 of Set 9 | mana
# Processing Record 27 of Set 9 | kenai
# Processing Record 28 of Set 9 | sayyan
# Processing Record 29 of Set 9 | souillac
# Processing Record 30 of Set 9 | deniliquin
# Processing Record 31 of Set 9 | andra
# Processing Record 32 of Set 9 | madona
# Processing Record 33 of Set 9 | maku
# Processing Record 34 of Set 9 | kehtna
# Processing Record 35 of Set 9 | bandarbeyla
# Processing Record 36 of Set 9 | makaryev
# Processing Record 37 of Set 9 | sinop
# Processing Record 38 of Set 9 | port-gentil
# Processing Record 39 of Set 9 | yima
# Processing Record 40 of Set 9 | kedrovyy
# Processing Record 41 of Set 9 | yefimovskiy
# City not found. Skipping...
# Processing Record 42 of Set 9 | tullahoma
# Processing Record 43 of Set 9 | kysyl-syr
# Processing Record 44 of Set 9 | bud
# Processing Record 45 of Set 9 | narsaq
# Processing Record 46 of Set 9 | kaitangata
# Processing Record 47 of Set 9 | lebowakgomo
# Processing Record 48 of Set 9 | opuwo
# Processing Record 49 of Set 9 | le port
# Processing Record 50 of Set 9 | tabas
# Processing Record 1 of Set 10 | amparo
# Processing Record 2 of Set 10 | vieques
# Processing Record 3 of Set 10 | sena madureira
# Processing Record 4 of Set 10 | ust-tsilma
# Processing Record 5 of Set 10 | eucaliptus
# Processing Record 6 of Set 10 | taoudenni
# Processing Record 7 of Set 10 | lorengau
# Processing Record 8 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 10 | dembi dolo
# Processing Record 10 of Set 10 | barao de melgaco
# Processing Record 11 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 12 of Set 10 | komsomolskiy
# Processing Record 13 of Set 10 | santa rosa
# Processing Record 14 of Set 10 | longyearbyen
# Processing Record 15 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 10 | tlapa
# City not found. Skipping...
# Processing Record 17 of Set 10 | praia
# Processing Record 18 of Set 10 | henties bay
# Processing Record 19 of Set 10 | hervey bay
# Processing Record 20 of Set 10 | inhuma
# Processing Record 21 of Set 10 | fukue
# Processing Record 22 of Set 10 | ishigaki
# Processing Record 23 of Set 10 | araouane
# Processing Record 24 of Set 10 | polonnaruwa
# Processing Record 25 of Set 10 | ukiah
# Processing Record 26 of Set 10 | beloha
# Processing Record 27 of Set 10 | villa carlos paz
# Processing Record 28 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 29 of Set 10 | asekeyevo
# Processing Record 30 of Set 10 | arlit
# Processing Record 31 of Set 10 | smithers
# Processing Record 32 of Set 10 | the valley
# Processing Record 33 of Set 10 | maningrida
# Processing Record 34 of Set 10 | lichuan
# Processing Record 35 of Set 10 | yebaishou
# Processing Record 36 of Set 10 | imeni zhelyabova
# Processing Record 37 of Set 10 | price
# Processing Record 38 of Set 10 | iberia
# Processing Record 39 of Set 10 | colesberg
# Processing Record 40 of Set 10 | wenshang
# Processing Record 41 of Set 10 | mount isa
# Processing Record 42 of Set 10 | igrim
# Processing Record 43 of Set 10 | madaoua
# Processing Record 44 of Set 10 | alice springs
# Processing Record 45 of Set 10 | lincoln
# Processing Record 46 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 47 of Set 10 | mnogovershinnyy
# Processing Record 48 of Set 10 | saint john
# Processing Record 49 of Set 10 | cherkasskoye
# Processing Record 50 of Set 10 | keti bandar
# Processing Record 1 of Set 11 | sironj
# Processing Record 2 of Set 11 | port-cartier
# Processing Record 3 of Set 11 | golpayegan
# Processing Record 4 of Set 11 | denpasar
# Processing Record 5 of Set 11 | moron
# Processing Record 6 of Set 11 | mount gambier
# Processing Record 7 of Set 11 | dongying
# Processing Record 8 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 11 | half moon bay
# Processing Record 10 of Set 11 | valleyview
# Processing Record 11 of Set 11 | puerto del rosario
# Processing Record 12 of Set 11 | port blair
# Processing Record 13 of Set 11 | tarko-sale
# Processing Record 14 of Set 11 | itarema
# Processing Record 15 of Set 11 | vytegra
# Processing Record 16 of Set 11 | macanal
# Processing Record 17 of Set 11 | miramar
# Processing Record 18 of Set 11 | afanasyevo
# City not found. Skipping...
# Processing Record 19 of Set 11 | ancud
# Processing Record 20 of Set 11 | puerto baquerizo moreno
# Processing Record 21 of Set 11 | tiarei
# Processing Record 22 of Set 11 | lagoa
# Processing Record 23 of Set 11 | namatanai
# Processing Record 24 of Set 11 | zhezkazgan
# Processing Record 25 of Set 11 | bull savanna
# Processing Record 26 of Set 11 | voh
# Processing Record 27 of Set 11 | batemans bay
# Processing Record 28 of Set 11 | provideniya
# Processing Record 29 of Set 11 | liberal
# Processing Record 30 of Set 11 | chegdomyn
# Processing Record 31 of Set 11 | laval
# Processing Record 32 of Set 11 | tutoia
# Processing Record 33 of Set 11 | havoysund
# Processing Record 34 of Set 11 | cherskiy
# Processing Record 35 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 36 of Set 11 | pahrump
# Processing Record 37 of Set 11 | buraydah
# Processing Record 38 of Set 11 | chabahar
# Processing Record 39 of Set 11 | saint-joseph
# Processing Record 40 of Set 11 | portland
# Processing Record 41 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 11 | glace bay
# Processing Record 43 of Set 11 | axim
# Processing Record 44 of Set 11 | havre-saint-pierre
# Processing Record 45 of Set 11 | cam pha
# City not found. Skipping...
# Processing Record 46 of Set 11 | warmbad
# Processing Record 47 of Set 11 | lianran
# Processing Record 48 of Set 11 | pochutla
# Processing Record 49 of Set 11 | viedma
# Processing Record 50 of Set 11 | port lincoln
# Processing Record 1 of Set 12 | aklavik
# Processing Record 2 of Set 12 | roma
# Processing Record 3 of Set 12 | oudtshoorn
# Processing Record 4 of Set 12 | tombouctou
# Processing Record 5 of Set 12 | grand-lahou
# Processing Record 6 of Set 12 | visnes
# Processing Record 7 of Set 12 | westport
# Processing Record 8 of Set 12 | mackay
# Processing Record 9 of Set 12 | lodwar
# Processing Record 10 of Set 12 | gimli
# Processing Record 11 of Set 12 | kalmunai
# Processing Record 12 of Set 12 | severodvinsk
# Processing Record 13 of Set 12 | csorna
# Processing Record 14 of Set 12 | alvorada
# Processing Record 15 of Set 12 | hudson bay
# Processing Record 16 of Set 12 | jumla
# Processing Record 17 of Set 12 | tonantins
# Processing Record 18 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 12 | chiredzi
# Processing Record 20 of Set 12 | tilsonburg
# City not found. Skipping...
# Processing Record 21 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 22 of Set 12 | presidencia roque saenz pena
# Processing Record 23 of Set 12 | oksfjord
# Processing Record 24 of Set 12 | renukut
# Processing Record 25 of Set 12 | sirvintos
# Processing Record 26 of Set 12 | port keats
# Processing Record 27 of Set 12 | kostino
# Processing Record 28 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 29 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 30 of Set 12 | temir
# Processing Record 31 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 12 | nadvoitsy
# Processing Record 33 of Set 12 | bethel
# Processing Record 34 of Set 12 | bafia
# Processing Record 35 of Set 12 | kerema
# Processing Record 36 of Set 12 | zhigansk
# Processing Record 37 of Set 12 | itamaraca
# Processing Record 38 of Set 12 | alanya
# Processing Record 39 of Set 12 | virbalis
# Processing Record 40 of Set 12 | glendive
# Processing Record 41 of Set 12 | matara
# Processing Record 42 of Set 12 | caravelas
# Processing Record 43 of Set 12 | rocha
# Processing Record 44 of Set 12 | villazon
# Processing Record 45 of Set 12 | wajir
# Processing Record 46 of Set 12 | beaverlodge
# Processing Record 47 of Set 12 | byron bay
# Processing Record 48 of Set 12 | san pedro
# Processing Record 49 of Set 12 | mizdah
# Processing Record 50 of Set 12 | chandbali
# Processing Record 1 of Set 13 | tari
# Processing Record 2 of Set 13 | marawi
# Processing Record 3 of Set 13 | coquimbo
# Processing Record 4 of Set 13 | tiruvallur
# Processing Record 5 of Set 13 | okandja
# City not found. Skipping...
# Processing Record 6 of Set 13 | noumea
# Processing Record 7 of Set 13 | hami
# Processing Record 8 of Set 13 | parana
# Processing Record 9 of Set 13 | payo
# Processing Record 10 of Set 13 | kampong chhnang
# Processing Record 11 of Set 13 | ust-koksa
# Processing Record 12 of Set 13 | ghanzi
# Processing Record 13 of Set 13 | badgam
# City not found. Skipping...
# Processing Record 14 of Set 13 | mairi
# Processing Record 15 of Set 13 | parabel
# Processing Record 16 of Set 13 | kabanjahe
# Processing Record 17 of Set 13 | macas
# Processing Record 18 of Set 13 | marystown
# Processing Record 19 of Set 13 | tadine
# Processing Record 20 of Set 13 | nizwa
# Processing Record 21 of Set 13 | kruisfontein
# Processing Record 22 of Set 13 | mirzapur
# Processing Record 23 of Set 13 | conway
# Processing Record 24 of Set 13 | acarau
# Processing Record 25 of Set 13 | raudeberg
# Processing Record 26 of Set 13 | zinacantan
# Processing Record 27 of Set 13 | duldurga
# Processing Record 28 of Set 13 | golden
# Processing Record 29 of Set 13 | tshikapa
# Processing Record 30 of Set 13 | virginia beach
# Processing Record 31 of Set 13 | faya
# Processing Record 32 of Set 13 | paris
# Processing Record 33 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 34 of Set 13 | egvekinot
# Processing Record 35 of Set 13 | dagumba-an
# Processing Record 36 of Set 13 | russellville
# Processing Record 37 of Set 13 | poum
# Processing Record 38 of Set 13 | springbok
# Processing Record 39 of Set 13 | zyryanka
# Processing Record 40 of Set 13 | porto murtinho
# Processing Record 41 of Set 13 | puerto carreno
# Processing Record 42 of Set 13 | sorong
# Processing Record 43 of Set 13 | sibu
# Processing Record 44 of Set 13 | severomuysk
# Processing Record 45 of Set 13 | grand gaube
# Processing Record 46 of Set 13 | vanavara
# Processing Record 47 of Set 13 | gawler
# Processing Record 48 of Set 13 | arroio dos ratos
# Processing Record 49 of Set 13 | lucatan
# City not found. Skipping...
# Processing Record 50 of Set 13 | saint-denis
# Processing Record 1 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 2 of Set 14 | alofi
# Processing Record 3 of Set 14 | parauna
# Processing Record 4 of Set 14 | pichayevo
# Processing Record 5 of Set 14 | nagato
# Processing Record 6 of Set 14 | male
# Processing Record 7 of Set 14 | tafalla
# Processing Record 8 of Set 14 | balassagyarmat
# Processing Record 9 of Set 14 | mudanya
# Processing Record 10 of Set 14 | agadez
# Processing Record 11 of Set 14 | ossora
# Processing Record 12 of Set 14 | solnechnyy
# Processing Record 13 of Set 14 | ragandang
# Processing Record 14 of Set 14 | keningau
# Processing Record 15 of Set 14 | praia da vitoria
# Processing Record 16 of Set 14 | rockland
# Processing Record 17 of Set 14 | fort frances
# Processing Record 18 of Set 14 | tomatlan
# Processing Record 19 of Set 14 | skibotn
# Processing Record 20 of Set 14 | gigmoto
# Processing Record 21 of Set 14 | manali
# Processing Record 22 of Set 14 | voi
# Processing Record 23 of Set 14 | jieshi
# Processing Record 24 of Set 14 | juquia
# Processing Record 25 of Set 14 | dong hoi
# Processing Record 26 of Set 14 | kuytun
# Processing Record 27 of Set 14 | alekseyevsk
# Processing Record 28 of Set 14 | chinhoyi
# Processing Record 29 of Set 14 | marzuq
# Processing Record 30 of Set 14 | erenhot
# Processing Record 31 of Set 14 | katangli
# Processing Record 32 of Set 14 | tsabong
# Processing Record 33 of Set 14 | chilca
# Processing Record 34 of Set 14 | yialos
# City not found. Skipping...
# Processing Record 35 of Set 14 | dalbandin
# Processing Record 36 of Set 14 | wufeng
# Processing Record 37 of Set 14 | juneau
# Processing Record 38 of Set 14 | lashio
# Processing Record 39 of Set 14 | marsh harbour
# Processing Record 40 of Set 14 | paluan
# Processing Record 41 of Set 14 | vila velha
# Processing Record 42 of Set 14 | saint anthony
# Processing Record 43 of Set 14 | bloemhof
# Processing Record 44 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 14 | pangkalanbuun
# Processing Record 46 of Set 14 | poopo
# Processing Record 47 of Set 14 | sharan
# Processing Record 48 of Set 14 | shimoda
# Processing Record 49 of Set 14 | ustka
# Processing Record 50 of Set 14 | kulhudhuffushi
# Processing Record 1 of Set 15 | gilgit
# Processing Record 2 of Set 15 | aden
# Processing Record 3 of Set 15 | high rock
# Processing Record 4 of Set 15 | osypenko
# Processing Record 5 of Set 15 | ndele
# Processing Record 6 of Set 15 | jiuquan
# Processing Record 7 of Set 15 | eyl
# Processing Record 8 of Set 15 | spearfish
# Processing Record 9 of Set 15 | sao felix do xingu
# Processing Record 10 of Set 15 | juarez
# Processing Record 11 of Set 15 | nizhniy ufaley
# Processing Record 12 of Set 15 | broome
# Processing Record 13 of Set 15 | kerki
# City not found. Skipping...
# Processing Record 14 of Set 15 | durango
# Processing Record 15 of Set 15 | juli
# Processing Record 16 of Set 15 | tongliao
# Processing Record 17 of Set 15 | doctor arroyo
# Processing Record 18 of Set 15 | acajutla
# Processing Record 19 of Set 15 | colomi
# Processing Record 20 of Set 15 | doha
# Processing Record 21 of Set 15 | dasoguz
# Processing Record 22 of Set 15 | rantauprapat
# Processing Record 23 of Set 15 | nemuro
# Processing Record 24 of Set 15 | aykhal
# Processing Record 25 of Set 15 | salym
# Processing Record 26 of Set 15 | barabai
# Processing Record 27 of Set 15 | tocopilla
# Processing Record 28 of Set 15 | la ronge
# Processing Record 29 of Set 15 | harsewinkel
# Processing Record 30 of Set 15 | toliary
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 665

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Clyde River  70.4692  -68.5914     25.03        86         100       14.97
# 1     Cidreira -30.1811  -50.2056     58.96        87           2        5.26
# 2       Vostok  46.4856  135.8833     35.92        43          64       11.92
# 3    Upernavik  72.7868  -56.1549     20.01        78          91        5.10
# 4        Muros  42.7762   -9.0603     55.09        95           1        4.79
#
#   Country Current Description
# 0      CA     overcast clouds
# 1      BR           clear sky
# 2      RU       broken clouds
# 3      GL     overcast clouds
# 4      ES           clear sky

# %%
# Display sample data
city_data_df.head(10)

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Clyde River      CA  70.4692  -68.5914     25.03        86         100
# 1       Cidreira      BR -30.1811  -50.2056     58.96        87           2
# 2         Vostok      RU  46.4856  135.8833     35.92        43          64
# 3      Upernavik      GL  72.7868  -56.1549     20.01        78          91
# 4          Muros      ES  42.7762   -9.0603     55.09        95           1
# ..           ...     ...      ...       ...       ...       ...         ...
# 660        Salym      RU  60.0625   71.4789     40.89        97         100
# 661      Barabai      ID  -2.5833  115.3833     80.85        85         100
# 662    Tocopilla      CL -22.0920  -70.1979     58.69        70          16
# 663     La Ronge      CA  55.1001 -105.2842     55.65        54          20
# 664  Harsewinkel      DE  51.9667    8.2333     57.16        75          95
#
#      Wind Speed Current Description
# 0         14.97     overcast clouds
# 1          5.26           clear sky
# 2         11.92       broken clouds
# 3          5.10     overcast clouds
# 4          4.79           clear sky
# ..          ...                 ...
# 660        2.77          light rain
# 661        1.68     overcast clouds
# 662        5.10          few clouds
# 663        9.22               smoke
# 664        9.42     overcast clouds
#
# [665 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label='City_ID')
